# %%
'''step 1>>> training data
extract important data from the gait rite

step2: collect actual data(gait rite) and my own data for mapping


step3: organize actual data and my own data in single file for training

step4: devide this data into training and testing dataset

step5: think about different ml model for mapping your data with actual data

step6: model training and evaluation






'''
