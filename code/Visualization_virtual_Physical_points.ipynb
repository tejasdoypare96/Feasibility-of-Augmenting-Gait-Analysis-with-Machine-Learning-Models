# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# Virtual coordinates (Q) - the red points you already have
virtual_points = [
    (1223, 1745), (1526, 1758), (1842, 1768),
    (1370, 1828), (1679, 1842), (1217, 1973),
    (1366, 1985), (1518, 1992), (1673, 1998),
    (1833, 2005), (1362, 2139), (1666, 2163),
    (1213, 2205), (1512, 2226), (1823, 2245)
]

# Transformed coordinates (calculated from P using R and T)
# These coordinates should be obtained from your transformation calculation
transformed_points = [
    # Example coordinates - replace with your actual transformed points
    (x, y) for x, y in zip(P[0], P[1])  # Using your P matrix from previous code
]

def visualize_points(image_path, virtual_points, transformed_points):
    # Read the image
    image = cv2.imread(image_path)

    # Plot virtual points in red
    for i, (x, y) in enumerate(virtual_points):
        # Draw red circle
        cv2.circle(image, (int(x), int(y)), 5, (0, 0, 255), -1)  # Red color
        # Add point number
        cv2.putText(image, str(i+1), (int(x)-10, int(y)-10),
                   cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255), 2)

    # Plot transformed points in black
    for i, (x, y) in enumerate(transformed_points):
        # Draw black circle
        cv2.circle(image, (int(x), int(y)), 5, (0, 0, 0), -1)  # Black color
        # Add point number
        cv2.putText(image, str(i+1), (int(x)-10, int(y)-10),
                   cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 0), 2)

    # Display the image
    cv2_imshow(image)

    # Save the image
    cv2.imwrite('visualization_result.jpg', image)

# Call the function
image_path = '/content/IMG-A1.jpg'  # Replace with your actual image path
visualize_points(image_path, virtual_points, transformed_points)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import cv2
from google.colab.patches import cv2_imshow

# Define the points
virtual_points = [
    (1223, 1745), (1526, 1758), (1842, 1768),
    (1370, 1828), (1679, 1842), (1217, 1973),
    (1366, 1985), (1518, 1992), (1673, 1998),
    (1833, 2005), (1362, 2139), (1666, 2163),
    (1213, 2205), (1512, 2226), (1823, 2245)
]

# phy_points = [(1205.31, 1752.08),
#  (1521.46, 1745.47),
#  (1859.79, 1783.28),
#  (1379.76, 1814.93),
#  (1657.90, 1862.23),
#  (1218.26, 1980.03),
#  (1389.73, 1975.02),
#  (1506.10, 1997.75),
#  (1672.89, 2004.16),
#  (1844.02, 1985.55),
#  (1384.51, 2146.35),
#  (1653.82, 2191.11),
#  (1198.59, 2223.16),
#  (1485.73, 2242.50),
#  (1840.86, 2275.06)]

phy_points = [(1228.5711493421934, 1750.708522288142),
 (1531.630856398215, 1764.17188637465),
 (1834.6905634542363, 1777.6352504611582),
 (1376.735161848577, 1833.2051310954014),
 (1679.7948689045986, 1846.6684951819095),
 (1218.4736262773122, 1978.003302580158),
 (1370.003479805323, 1984.7349846234122),
 (1521.5333333333335, 1991.4666666666662),
 (1673.0631868613443, 1998.19834870992),
 (1824.593040389355, 2004.9300307531744),
 (1363.271797762069, 2136.2648381514227),
 (1666.3315048180903, 2149.7282022379313),
 (1208.376103212431, 2205.2980828721743),
 (1511.4358102684525, 2218.7614469586824),
 (1814.4955173244741, 2232.2248110451906)]



# Load image (Ensure that the path is correct)
img = cv2.imread('/content/IMG-A1.jpg')

# Check if the image is loaded properly
if img is None:
    print("Error: Image not loaded. Check the file path.")
else:
    # Draw red circles at the given virtual points
    for point in virtual_points:
        cv2.circle(img, point, 3, (0, 0, 255), -1)  # Red color in BGR

    # Draw green circles at the given physical points
    for p in phy_points:
        phy_int = tuple(int(coord) for coord in p)
        cv2.circle(img, phy_int, 3, (255, 0, 0), -1) # Blue

    # Display the image in Google Colab
    cv2_imshow(img)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
